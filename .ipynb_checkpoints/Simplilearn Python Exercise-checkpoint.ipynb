# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.40.40%20PM.png](attachment:Screenshot%202023-09-27%20at%204.40.40%20PM.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel("Olympic 2012 Medal Tally.xlsx",index_col = 0, skiprows = 2)
df.reset_index(drop = True, inplace = True)
df
# Out:
#          Country Country Code  Year  Gold  Silver  Bronze
# 0  Great Britain          GBR  2012    29      17      19
# 1         China           CHN  2012    38      28      22
# 2         Russia          RUS  2012    24      25      32
# 3  United States           US  2012    46      28      29
# 4          Korea          KOR  2012    13       8       7
# 5          Japan          JPN  2012     7      14      17
# 6        Germany          GER  2012    11      11      14

# %%
#1.
df[["Country","Gold"]][df["Gold"] == df["Gold"].max()]
# Out:
#          Country  Gold
# 3  United States    46

# %%
#2.
(df[["Country","Gold"]][df["Gold"] > 20]).sort_values("Gold", ascending = False)
# Out:
#          Country  Gold
# 3  United States    46
# 1         China     38
# 0  Great Britain    29
# 2         Russia    24

# %%
#3.
df[["Gold", "Silver", "Bronze"]]
# Out:
#    Gold  Silver  Bronze
# 0    29      17      19
# 1    38      28      22
# 2    24      25      32
# 3    46      28      29
# 4    13       8       7
# 5     7      14      17
# 6    11      11      14

# %%
#4.
df[["Country","Gold"]]
# Out:
#          Country  Gold
# 0  Great Britain    29
# 1         China     38
# 2         Russia    24
# 3  United States    46
# 4          Korea    13
# 5          Japan     7
# 6        Germany    11

# %%
#5.
df["Total"] = df["Gold"] +  df["Silver"] +  df["Bronze"]
# Out:
#          Country  Total
# 0  Great Britain     65
# 1         China      88
# 2         Russia     81
# 3  United States    103
# 4          Korea     28
# 5          Japan     38
# 6        Germany     36

# %%
df_medal = df[["Country", "Total"]]
df_medal = df_medal.sort_values("Total", ascending = False)
df_medal.reset_index(drop = True)
# Out:
#          Country  Total
# 0  United States    103
# 1         China      88
# 2         Russia     81
# 3  Great Britain     65
# 4          Japan     38
# 5        Germany     36
# 6          Korea     28

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.40.46%20PM.png](attachment:Screenshot%202023-09-27%20at%204.40.46%20PM.png)

# %%
ls
# Out:
# Advertising.csv*                       Salaries.csv
# Boston 2.csv                           Simplilearn Python Exercise.ipynb
# Boston.csv                             driver-data.csv*
# BostonHousing.csv                      faa_ai_prelim.csv
# Case Study - healthcare Industry.docx  health care diabetes.csv
# FDNY.csv                               health care diabetes.xlsx
# Mall_Customers.csv                     mtcars.csv
# Olympic 2012 Medal Tally.xlsx          pima-indians-diabetes.csv*
# Python Exercise.ipynb                  project.csv
# README.md                              zoo.csv*

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.41.31%20PM.png](attachment:Screenshot%202023-09-27%20at%204.41.31%20PM.png)

# %%
# x is T/F questions.
# y is MCQ based questions.
# Equations: x + y = 30
# 4x + 9y = 150
A = np.array([[1,1],[4,9]])
B = np.array([30,150])
X = np.linalg.solve(A,B)
print(X)
# Out:
# [24.  6.]

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.41.37%20PM.png](attachment:Screenshot%202023-09-27%20at%204.41.37%20PM.png)

# %%
values = np.random.rand(20)
values
# Out:
# array([0.29698263, 0.66650511, 0.81221696, 0.85895258, 0.38150844,
#        0.90638557, 0.64944261, 0.86797369, 0.45212093, 0.9745498 ,
#        0.96520786, 0.68654636, 0.58011757, 0.53655444, 0.09402653,
#        0.61958637, 0.11639709, 0.49112407, 0.96402628, 0.77699132])

# %%
from scipy.stats import norm
# Out:
# 7.69459862670642e-23

# %%
#1.
norm.pdf(x = values[0:10], loc = 0, scale = 1)
# Out:
# array([0.38173147, 0.31948241, 0.28685262, 0.27586648, 0.37094077,
#        0.26455505, 0.32308934, 0.27372599, 0.36018222, 0.24812759])

# %%
#2.
norm.cdf(x = values[0:14], loc = 0, scale = 1)
# Out:
# array([0.61676011, 0.74745585, 0.79166643, 0.80481666, 0.64858699,
#        0.8176341 , 0.74197384, 0.80729563, 0.67440907, 0.83510819,
#        0.83277964, 0.75381568, 0.71908233, 0.70421229])

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.42.47%20PM.png](attachment:Screenshot%202023-09-27%20at%204.42.47%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.43.02%20PM.png](attachment:Screenshot%202023-09-27%20at%204.43.02%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.43.12%20PM.png](attachment:Screenshot%202023-09-27%20at%204.43.12%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.43.21%20PM.png](attachment:Screenshot%202023-09-27%20at%204.43.21%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.44.34%20PM.png](attachment:Screenshot%202023-09-27%20at%204.44.34%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.45.00%20PM.png](attachment:Screenshot%202023-09-27%20at%204.45.00%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.45.09%20PM.png](attachment:Screenshot%202023-09-27%20at%204.45.09%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.46.14%20PM.png](attachment:Screenshot%202023-09-27%20at%204.46.14%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.46.21%20PM.png](attachment:Screenshot%202023-09-27%20at%204.46.21%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-27%20at%204.46.34%20PM.png](attachment:Screenshot%202023-09-27%20at%204.46.34%20PM.png)
